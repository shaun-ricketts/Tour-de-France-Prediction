# %% [markdown]
# Factors not captured in the analysis:
# - Parkour of the race
# - Abandonments and unexpected time loss
#     - Riders who lost time due to crashes, injuries, illness and other reasons out of their control.
# - The weather
#     - Some riders do better in wet, windy or hot conditions than others.
#
# Factors not used due to potential inaccuracies:
# - Height
#     - Value may not be accurate in all cases.
# - Weight
#     - The value taken for each rider is their most recent value.
#     - A rider's weight fluxuates often during a season.
#     - The assumption is that every rider at the Tour will be at their ideal weight coming into it.

# %% [markdown]
# # Import Libraries and Set Directories

# %%
import pandas as pd
import numpy as np

from sklearn.decomposition import PCA
from sklearn import metrics
from sklearn import linear_model
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

from sklearn import preprocessing
from sklearn.impute import KNNImputer

from sklearn.metrics import accuracy_score

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.linear_model import Ridge

import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

#import plotly.graph_objs as go
#from plotly.offline import iplot

import matplotlib as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
import tensorflow.compat.v2.feature_column as fc
import tensorflow as tf
from tensorflow.keras.models import Sequential

import keras
import keras.backend as kb
from keras.layers import Dense, Dropout, LSTM, BatchNormalization
from keras.callbacks import TensorBoard
from keras.callbacks import ModelCheckpoint
from keras.optimizers import adam_v2

# %%
dPath = "D:/Data/cycling/"

# %% [markdown]
# # Define Functions

# %% [markdown]
# ## Clean 2021 Data

# %%
def clean_2021_data(tdf_2021):
    tdf_2021.replace("AttError","Unknown",inplace=True)
    
    # Fill missing data for height and weight
    tdf_2021["Weight"] = np.where(tdf_2021["URL"]=="mark-donovan", 70, tdf_2021["Height"])

    # Create GC and SBW columns
    tdf_2021["GC"] = np.nan
    tdf_2021["Seconds Behind Winner"] = np.nan
    
    # Insert Team Leader Data
    tdf_2021["Team Leader"] = 0
    # UAE
    tdf_2021["Team Leader"] = np.where(tdf_2021["URL"]=="tadej-pogacar", 1, tdf_2021["Team Leader"])
    # Lotto-NL
    tdf_2021["Team Leader"] = np.where(tdf_2021["URL"]=="primoz-roglic", 1, tdf_2021["Team Leader"])
    # Ineos
    tdf_2021["Team Leader"] = np.where(tdf_2021["URL"]=="geraint-thomas", 1, tdf_2021["Team Leader"])
    # Israel
    tdf_2021["Team Leader"] = np.where(tdf_2021["URL"]=="christopher-froome", 1, tdf_2021["Team Leader"])
    # Trek
    tdf_2021["Team Leader"] = np.where(tdf_2021["URL"]=="vincenzo-nibali", 1, tdf_2021["Team Leader"])
    # Quickstep
    tdf_2021["Team Leader"] = np.where(tdf_2021["URL"]=="julian-alaphilippe", 1, tdf_2021["Team Leader"])
    # Movistar
    tdf_2021["Team Leader"] = np.where(tdf_2021["URL"]=="miguel-angel-lopez", 1, tdf_2021["Team Leader"])
    # BORA
    tdf_2021["Team Leader"] = np.where(tdf_2021["URL"]=="peter-sagan", 1, tdf_2021["Team Leader"])
    # FDJ
    tdf_2021["Team Leader"] = np.where(tdf_2021["URL"]=="david-gaudu", 1, tdf_2021["Team Leader"])
    # Cofidis
    tdf_2021["Team Leader"] = np.where(tdf_2021["URL"]=="guillaume-martin", 1, tdf_2021["Team Leader"])
    # Alpecin
    tdf_2021["Team Leader"] = np.where(tdf_2021["URL"]=="mathieu-van-der-poel", 1, tdf_2021["Team Leader"])
    # EF
    tdf_2021["Team Leader"] = np.where(tdf_2021["URL"]=="rigoberto-uran", 1, tdf_2021["Team Leader"])
    # AG2R
    tdf_2021["Team Leader"] = np.where(tdf_2021["URL"]=="benoit-cosnefroy", 1, tdf_2021["Team Leader"])
    # Arkea
    tdf_2021["Team Leader"] = np.where(tdf_2021["URL"]=="warren-barguil", 1, tdf_2021["Team Leader"])
    # DSM
    tdf_2021["Team Leader"] = np.where(tdf_2021["URL"]=="soren-kragh-andersen", 1, tdf_2021["Team Leader"])
    # Lotto Soudal
    tdf_2021["Team Leader"] = np.where(tdf_2021["URL"]=="caleb-ewan", 1, tdf_2021["Team Leader"])
    # Bahrain
    tdf_2021["Team Leader"] = np.where(tdf_2021["URL"]=="jack-haig", 1, tdf_2021["Team Leader"])
    # BikeExchange
    tdf_2021["Team Leader"] = np.where(tdf_2021["URL"]=="michael-matthews", 1, tdf_2021["Team Leader"])
    # Astana
    tdf_2021["Team Leader"] = np.where(tdf_2021["URL"]=="jakob-fuglsang", 1, tdf_2021["Team Leader"])
    # Quebeka
    tdf_2021["Team Leader"] = np.where(tdf_2021["URL"]=="sergio-luis-henao", 1, tdf_2021["Team Leader"])
    #Total Energies
    tdf_2021["Team Leader"] = np.where(tdf_2021["URL"]=="pierre-latour", 1, tdf_2021["Team Leader"])
    # Wanty
    tdf_2021["Team Leader"] = np.where(tdf_2021["URL"]=="louis-meintjes", 1, tdf_2021["Team Leader"])
    # B&B
    tdf_2021["Team Leader"] = np.where(tdf_2021["URL"]=="bryan-coquard", 1, tdf_2021["Team Leader"])

    return tdf_2021

# %% [markdown]
# ## Impute Nulls

# %%
def ImputeNulls(df):
    df = df[df["GC"]!="DNF"]
    #all_cols = df.columns.to_list()
    #cols = [e for e in all_cols if e not in ('Rider','URL','GC','Seconds Behind Winner','Top10','Team','Nationality')]
    
    cols = ["Age","AverageResult_2UWT","AverageResult_2HC","BestResult_2UWT","BestResult_2HC","BestGTFinish",
            "numGTs","WT"]
    
    imputer = KNNImputer(n_neighbors=2)
    df[cols] = imputer.fit_transform(df[cols])
    
    return df

# %% [markdown]
# ## Add Team Information

# %%
def AddTeammateData(tdf_train):
    tdf_team = pd.DataFrame()

    for team in tdf_train["Team"].unique():
        df = tdf_train[tdf_train["Team"]==team]
        
        # remove df["Team Leader"].max()

        for rider in df["Rider"].unique():
            r = df[df["Rider"]==rider]
            teammates = df[df["Rider"]!=rider]
            
            teammates = teammates[teammates["Team Leader"]!=1]

            teammates = teammates.groupby(["Team","Year"]).agg(Age_Team=("Age","mean"),
                                                               numGTs_Team=("numGTs","sum"),
                                                  BestGTFinish_Team=("BestGTFinish","max")).reset_index()
            #dom.rename(columns={"Age":"Age_Team","numGTs":"numGTs_Team","Starts":"Starts_Team"}, inplace=True)
            r = r.merge(teammates, on=['Team','Year'], how='left')

            tdf_team = tdf_team.append(r)

    return tdf_team

# %% [markdown]
# ## Clean Train Data

# %%
def clean_train_data(tdf_train):
    # Remove rider with errors
    tdf_train = tdf_train[tdf_train["Rider"]!='BONNET WILLIAM']
    
    # Insert Years Since First/Last Grand Tour values
    tdf_train["YearsSinceFirstGT"] = -1
    tdf_train["YearsSinceFirstGT"] = np.where(tdf_train["FirstGT"].isna(), tdf_train["YearsSinceFirstGT"], tdf_train["Year"]-tdf_train["FirstGT"])
    tdf_train["YearsSinceLastGT"] = -1
    tdf_train["YearsSinceLastGT"] = np.where(tdf_train["LastGT"].isna(), tdf_train["YearsSinceLastGT"], tdf_train["Year"]-tdf_train["LastGT"])
    # Add value for whether rider rode Giro d'Italia that year or not
    tdf_train["Giro"] = np.where((tdf_train["YearsSinceLastGT"]==0) & (tdf_train["Year"]!=2020) , 1, 0)
    
    # Fill NA values for specific columns
    tdf_train["numTours"].fillna(0, inplace=True)
    tdf_train["numGiros"].fillna(0, inplace=True)
    tdf_train["numVueltas"].fillna(0, inplace=True)
    tdf_train["numGTs"].fillna(0, inplace=True)
    tdf_train["NumGTDNFs"].fillna(0, inplace=True)
    tdf_train["FirstGT"].fillna(tdf_train["Year"], inplace=True)
    tdf_train["LastGT"].fillna(tdf_train["Year"], inplace=True)
    tdf_train["FirstTour"].fillna(tdf_train["Year"], inplace=True)
    tdf_train["LastTour"].fillna(tdf_train["Year"], inplace=True)
    
    # Merge with Team Data to get value for whether rider rides for World-Tour team or not
    tdf_train = tdf_train.merge(teams, on=['Team','Year'], how='left')
    tdf_train["WT"] = np.where(tdf_train["Rank"]=="WT", 1, 0)
    del tdf_train["Rank"]
    
    # Impute Nulls for specific columns
    tdf_train = ImputeNulls(tdf_train)
    
    # Add Team information
    tdf_train = AddTeammateData(tdf_train)
        
    return tdf_train

# %%
# Binary Variables = 'Team Leader', 'Giro', 'WT'

# %% [markdown]
# ## Normalize Data

# %%
def NormalizeData(df):
    all_cols = df.columns.to_list()
    #cols = [e for e in all_cols if e not in ('Rider','GC','Seconds Behind Winner','Top10','Year','Team','URL','Nationality')]
    # Include Binary Variables = 'Team Leader', 'Giro', 'WT'
    cols = [e for e in all_cols if e not in ('Rider','GC','Seconds Behind Winner','Top10','Year','Team','URL','Nationality','Team Leader', 'Giro', 'WT')]
    df[cols] = preprocessing.MinMaxScaler().fit_transform(df[cols])
    return df

# %% [markdown]
# ## Variance Inflation Factor

# %%
def calc_vif(df, features):
    df = df[features]
    # Calculate VIF
    vif = pd.DataFrame()
    vif["Variables"] = features
    vif["VIF"] = [variance_inflation_factor(df.values, i) for i in range(df.shape[1])]
    
    print("Variance Inflation Factor (if higher than 5 may need reviewing):")
    display(vif)

# %% [markdown]
# ## Model Statistics

# %%
# creating function to get model statistics
def get_stats(df, predictor, features):
    results = sm.OLS(df[predictor], df[features]).fit()
    print(results.summary())

# %% [markdown]
# ## Heatmap/Correlations

# %%
# Correlate and plot heatmap
def heatmap(df, predictor, features):
    features_ = features.copy()
    features_.append(predictor)
    hmap = df[features_]
    sns.heatmap(hmap.corr().round(2)[[predictor]].sort_values(predictor, ascending=False), cmap="coolwarm", vmin=-1, vmax=1)
    print("Correlations:")
    display(hmap.corr().round(2)[[predictor]].sort_values(predictor, ascending=False))

# %% [markdown]
# ## Plot Actual vs Predicted

# %%
# Plot the actual vs predicted values
def plot_actual_vs_pred(df, predictor):
    sns.lmplot(x = predictor + "_Actual", y = predictor + "_Pred", data=df, fit_reg=False, size=7)

# %%
# Plot the actual vs ranked predicted values
def plot_actual_vs_pred_ranked(df, predictor):
    sns.lmplot(x = predictor + "_Actual", y = predictor + "_Pred_Ranked", data=df, fit_reg=False, size=7)

# %% [markdown]
# ## TensorFlow (Keras)

# %%
def baseline_model():
    # create model
    model = Sequential()
    model.add(Dense(13, input_dim=13, kernel_initializer='normal', activation='relu'))
    model.add(Dense(1, kernel_initializer='normal'))
    # Compile model
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# %%
def KerasRegressionModel(train, predictor, features, test_year):
    # Split train and test data
    test = train[train["Year"]==test_year]
    train = train[train["Year"]<test_year]
    # Alternative
    #train, test = train_test_split(train)
    
    # Remove redundant columns
    del train["Year"]
    del test["Year"]
    del train["Rider"]
    
    if predictor == "GC":
        # Remove DNF values from training data
        train = train[train[predictor]!="DNF"]
        train.dropna(subset=[predictor],inplace=True)
        train[predictor] = train[predictor].astype(str).str[:-2].astype(int)

    # Normalize Train Data
    train =  NormalizeData(train)
    # Normalize Test data
    test = NormalizeData(test)
    
    if predictor == "GC":
        # Replace DNF values with 0
        test["GC"].fillna('0.0',inplace=True)
        test["GC"].replace("DNF",'0.0',inplace=True)
        test[predictor] = test[predictor].astype(str).str[:-2].astype(int)
    
    get_stats(train, predictor, features)
    calc_vif(train, features)
    heatmap(train, predictor, features)

    model = keras.Sequential([
    keras.layers.Dense(32, activation=tf.nn.relu, input_shape=[1]),
    keras.layers.Dense(32, activation=tf.nn.relu),
    keras.layers.Dense(32, activation=tf.nn.relu),
    keras.layers.Dense(1)])

    optimizer = tf.keras.optimizers.RMSprop(0.0099)
    model.compile(loss='mean_squared_error',optimizer="adam")
    model.fit(train[features], train[predictor],epochs=500)
   
    return test

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
def tf_Top10(train, features, test_year):
    
    # Add Top10
    train["GC_temp"] = train["GC"]
    train.dropna(subset=["GC_temp"], inplace=True)
    train["GC_temp"].replace("DNF",200.0,inplace=True)
    train["GC_temp"] = train["GC_temp"].astype(float).astype(int)
    train["Top10"] = 0
    train["Top10"] = np.where(train["GC_temp"]>10, 0, 1)
    del tdf_train["GC_temp"]
    
    # Split train and test data
    test = train[train["Year"]==test_year]
    train = train[train["Year"]<test_year]
    # Alternative
    #train, test = train_test_split(train)
    
    # Remove redundant columns
    del train["Year"]
    del test["Year"]
    del train["Rider"]
    
    display(train[["GC","Top10"]].head())
    
    model = Sequential()
    model.add(Dense(units=32, activation='relu', input_dim=len(features)))
    model.add(Dense(units=64, activation='relu'))
    model.add(Dense(units=1, activation='sigmoid'))
    
    model.compile(loss='binary_crossentropy', optimizer='sgd', metrics='accuracy')
    
    model.fit(train[features], train["Top10"], epochs=200, batch_size=32)
    
    test["Prediction"] = model.predict(test[features])
    #test["Prediction"] = [0 if val < 0.5 else 1 for val in test["Prediction"]]
    
    #print(accuracy_score(test["Top10"], test["Prediction"]))
    
    return test

# %% [markdown]
# ## TensorFlow Linear Regression

# %%
def tf_linpredictor(train, predictor, features, test_year, split, epochs, batch_size):

    cols = features.copy()
    cols.append(predictor)
    cols.append("Rider")
    cols.append("Year")
    train = train[cols]
        
    if split == "year":
        # Split train and test data
        test = train[train["Year"]==test_year]
        train = train[train["Year"]<test_year]
        del test["Year"]
        
    elif split == "sk":
        # Alternative
        train = train[train["Year"]!=2021]
        train, test = train_test_split(train, test_size=0.2)
    else:
        print("Invalid Split Name")
        return

    # Remove redundant columns
    del train["Year"]
    del train["Rider"]
    
    #Remove DNFs and Nulls from GC
    if predictor == "GC":
        # Replace DNF values with 0
        train["GC"].fillna('0.0',inplace=True)
        train["GC"].replace("DNF",'0.0',inplace=True)
        train["GC"].replace("",'0.0',inplace=True)
        train[predictor] = train[predictor].astype(float).astype(int)
        train = train[train["GC"]!=0]

    # Normalize Train Data
    train =  NormalizeData(train)
    # Normalize Test data
    test = NormalizeData(test)
        
    model = Sequential()
    model.add(Dense(units=256, kernel_initializer='normal', activation='relu', input_dim=len(features)))
    model.add(Dense(units=16, kernel_initializer='normal', activation='relu'))
    model.add(Dense(units=8, kernel_initializer='normal', activation='relu'))
    model.add(Dense(1, kernel_initializer='normal', activation='relu'))

    model.compile(loss='mean_squared_error',optimizer="adam", metrics='accuracy')
    
    model.fit(train[features], train[predictor],epochs=epochs, batch_size=batch_size)
    
    test["Prediction"] = model.predict(test[features])
    
    if split == "year":
        # Rank in order
        test["Prediction_Ranked"] = test["Prediction"].rank().astype(int)
        
        # Display Output
        display(test[["Rider",predictor,"Prediction_Ranked","Prediction"]].sort_values(by="Prediction").head(30))
        
        y_true = test[predictor]
        y_pred = test["Prediction"]

        print("Checking accuracy scores for Prediction:")

        print("Explained variance regression score: " + str(metrics.explained_variance_score(y_true, y_pred)))
        print("Maximum residual error: " + str(metrics.max_error(y_true, y_pred)))   
        print("Mean absolute error regression loss: " + str(metrics.mean_absolute_error(y_true, y_pred)))    
        print("Mean squared error regression loss: " + str(metrics.mean_squared_error(y_true, y_pred)))    
        print("Mean squared logarithmic error regression loss." + str(metrics.mean_squared_log_error(y_true, y_pred)))   
        print("Median absolute error regression loss: " + str(metrics.median_absolute_error(y_true, y_pred)))   
        print("Regression score function (R^2): " + str(metrics.r2_score(y_true, y_pred)))  
        print("Mean Poisson deviance regression loss: " + str(metrics.mean_poisson_deviance(y_true, y_pred)))
        print("Mean Tweedie deviance regression loss: " + str(metrics.mean_tweedie_deviance(y_true, y_pred)))
        
        y_pred = test["Prediction_Ranked"]
        print("\n")
        print("Checking accuracy scores for Prediction Ranked:")

        print("Explained variance regression score: " + str(metrics.explained_variance_score(y_true, y_pred)))
        print("Maximum residual error: " + str(metrics.max_error(y_true, y_pred)))   
        print("Mean absolute error regression loss: " + str(metrics.mean_absolute_error(y_true, y_pred)))    
        print("Mean squared error regression loss: " + str(metrics.mean_squared_error(y_true, y_pred)))    
        print("Mean squared logarithmic error regression loss." + str(metrics.mean_squared_log_error(y_true, y_pred)))   
        print("Median absolute error regression loss: " + str(metrics.median_absolute_error(y_true, y_pred)))   
        print("Regression score function (R^2): " + str(metrics.r2_score(y_true, y_pred)))  
        print("Mean Poisson deviance regression loss: " + str(metrics.mean_poisson_deviance(y_true, y_pred)))
        print("Mean Tweedie deviance regression loss: " + str(metrics.mean_tweedie_deviance(y_true, y_pred)))


    elif split == "sk":       
        # Display Output
        display(test[["Rider","Year","GC","Prediction"]].sort_values(by="Prediction").head(30))
        
        y_true = test[predictor]
        y_pred = test["Prediction"]

        print("Checking accuracy scores for Prediction:")

        print("Explained variance regression score: " + str(metrics.explained_variance_score(y_true, y_pred)))
        print("Maximum residual error: " + str(metrics.max_error(y_true, y_pred)))   
        print("Mean absolute error regression loss: " + str(metrics.mean_absolute_error(y_true, y_pred)))    
        print("Mean squared error regression loss: " + str(metrics.mean_squared_error(y_true, y_pred)))    
        print("Mean squared logarithmic error regression loss." + str(metrics.mean_squared_log_error(y_true, y_pred)))   
        print("Median absolute error regression loss: " + str(metrics.median_absolute_error(y_true, y_pred)))   
        print("Regression score function (R^2): " + str(metrics.r2_score(y_true, y_pred)))  
        print("Mean Poisson deviance regression loss: " + str(metrics.mean_poisson_deviance(y_true, y_pred)))
        print("Mean Tweedie deviance regression loss: " + str(metrics.mean_tweedie_deviance(y_true, y_pred)))
        
    return test

# %%
def tf_linpredictor_huber(train, predictor, features, test_year, split, epochs, batch_size):

    cols = features.copy()
    cols.append(predictor)
    cols.append("Rider")
    cols.append("Year")
    train = train[cols]
        
    if split == "year":
        # Split train and test data
        test = train[train["Year"]==test_year]
        train = train[train["Year"]<test_year]
        del test["Year"]
        
    elif split == "sk":
        # Alternative
        train = train[train["Year"]!=2021]
        train, test = train_test_split(train, test_size=0.2)
    else:
        print("Invalid Split Name")
        return

    # Remove redundant columns
    del train["Year"]
    del train["Rider"]
    
    #Remove DNFs and Nulls from GC
    if predictor == "GC":
        # Replace DNF values with 0
        train["GC"].fillna('0.0',inplace=True)
        train["GC"].replace("DNF",'0.0',inplace=True)
        train["GC"].replace("",'0.0',inplace=True)
        train[predictor] = train[predictor].astype(float).astype(int)
        train = train[train["GC"]!=0]

    # Normalize Train Data
    train =  NormalizeData(train)
    # Normalize Test data
    test = NormalizeData(test)
        
    model = Sequential()
    model.add(Dense(units=256, kernel_initializer='normal', activation='relu', input_dim=len(features)))
    model.add(Dense(units=16, kernel_initializer='normal', activation='relu'))
    model.add(Dense(units=8, kernel_initializer='normal', activation='relu'))
    model.add(Dense(1, kernel_initializer='normal', activation='relu'))

    model.compile(loss='huber',optimizer="adam", metrics='accuracy')
    
    model.fit(train[features], train[predictor],epochs=epochs, batch_size=batch_size)
    
    test["Prediction"] = model.predict(test[features])
    
    if split == "year":
        # Rank in order
        test["Prediction_Ranked"] = test["Prediction"].rank().astype(int)
        
        # Display Output
        display(test[["Rider",predictor,"Prediction_Ranked","Prediction"]].sort_values(by="Prediction").head(30))
        
        y_true = test[predictor]
        y_pred = test["Prediction"]

        print("Checking accuracy scores for Prediction:")

        print("Explained variance regression score: " + str(metrics.explained_variance_score(y_true, y_pred)))
        print("Maximum residual error: " + str(metrics.max_error(y_true, y_pred)))   
        print("Mean absolute error regression loss: " + str(metrics.mean_absolute_error(y_true, y_pred)))    
        print("Mean squared error regression loss: " + str(metrics.mean_squared_error(y_true, y_pred)))    
        print("Mean squared logarithmic error regression loss." + str(metrics.mean_squared_log_error(y_true, y_pred)))   
        print("Median absolute error regression loss: " + str(metrics.median_absolute_error(y_true, y_pred)))   
        print("Regression score function (R^2): " + str(metrics.r2_score(y_true, y_pred)))  
        #print("Mean Poisson deviance regression loss: " + str(metrics.mean_poisson_deviance(y_true, y_pred)))
        #print("Mean Tweedie deviance regression loss: " + str(metrics.mean_tweedie_deviance(y_true, y_pred)))
        
        y_pred = test["Prediction_Ranked"]
        print("\n")
        print("Checking accuracy scores for Prediction Ranked:")

        print("Explained variance regression score: " + str(metrics.explained_variance_score(y_true, y_pred)))
        print("Maximum residual error: " + str(metrics.max_error(y_true, y_pred)))   
        print("Mean absolute error regression loss: " + str(metrics.mean_absolute_error(y_true, y_pred)))    
        print("Mean squared error regression loss: " + str(metrics.mean_squared_error(y_true, y_pred)))    
        print("Mean squared logarithmic error regression loss." + str(metrics.mean_squared_log_error(y_true, y_pred)))   
        print("Median absolute error regression loss: " + str(metrics.median_absolute_error(y_true, y_pred)))   
        print("Regression score function (R^2): " + str(metrics.r2_score(y_true, y_pred)))  
        #print("Mean Poisson deviance regression loss: " + str(metrics.mean_poisson_deviance(y_true, y_pred)))
        #print("Mean Tweedie deviance regression loss: " + str(metrics.mean_tweedie_deviance(y_true, y_pred)))


    elif split == "sk":       
        # Display Output
        display(test[["Rider","Year","GC","Prediction"]].sort_values(by="Prediction").head(30))
        
        y_true = test[predictor]
        y_pred = test["Prediction"]

        print("Checking accuracy scores for Prediction:")

        print("Explained variance regression score: " + str(metrics.explained_variance_score(y_true, y_pred)))
        print("Maximum residual error: " + str(metrics.max_error(y_true, y_pred)))   
        print("Mean absolute error regression loss: " + str(metrics.mean_absolute_error(y_true, y_pred)))    
        print("Mean squared error regression loss: " + str(metrics.mean_squared_error(y_true, y_pred)))    
        print("Mean squared logarithmic error regression loss." + str(metrics.mean_squared_log_error(y_true, y_pred)))   
        print("Median absolute error regression loss: " + str(metrics.median_absolute_error(y_true, y_pred)))   
        print("Regression score function (R^2): " + str(metrics.r2_score(y_true, y_pred)))  
        #print("Mean Poisson deviance regression loss: " + str(metrics.mean_poisson_deviance(y_true, y_pred)))
        #print("Mean Tweedie deviance regression loss: " + str(metrics.mean_tweedie_deviance(y_true, y_pred)))
        
    return test

# %% [markdown]
# # Read and Clean Data

# %%
tdf_train = pd.read_csv(dPath+"tdf_train_2007_2020"+".csv")

# %%
#tdf_2021 = pd.read_csv(dPath+"tdf_2021"+".csv")

# %%
#tdf_2021 = clean_2021_data(tdf_2021)

# %%
#tdf_train = pd.concat([tdf_train, tdf_2021], ignore_index=True)

# %%
teams = pd.read_csv(dPath+"Teams.csv", engine="python")

# %%
#tdf_train.isna().sum()

# %%
tdf_train = clean_train_data(tdf_train)

# %%
tdf_train = tdf_train.replace('AttError','Unknown', regex=True)

# %%
tdf_train = tdf_train[~tdf_train["Days since last race"].isna()]

# %% [markdown]
# # Select Model Variables

# %%
# Print all possible feature variables
all_cols = tdf_train.columns.to_list()
all_cols = [e for e in all_cols if e not in ('Rider','Year','GC','Seconds Behind Winner','Top10','Team','URL','Nationality')]
print(all_cols)
# Out:
# ['Age', 'Team Leader', 'Days since last race', 'AverageResult_2UWT', 'AverageResult_2HC', 'BestResult_2UWT', 'BestResult_2HC', 'Total_KMs', 'UCIPoints', 'StageRaces', 'OneDayRaces', 'StageRaceDNFs', 'OneDayDNFs', 'AverageResult_2Other', 'BestResult_2Other', 'Height', 'Weight', 'numTours', 'numGiros', 'numVueltas', 'BestGTFinish', 'BestTourFinish', 'BestGTStageFinish', 'FirstGT', 'LastGT', 'FirstTour', 'LastTour', 'NumGTDNFs', 'numGTs', 'YearsSinceFirstGT', 'YearsSinceLastGT', 'Giro', 'WT', 'Age_Team', 'numGTs_Team', 'BestGTFinish_Team']

# %%
features1 = ['Age', 'BestResult_2UWT',
              'Total_KMs', 'UCIPoints', 'BestGTFinish', 'NumStageRaces',
              'NumDNFs', 'numGTs', 'YearsSinceLastGT', 'Giro', 'BestGTFinish_Team']

# %%
features2 = ['Age', 'BestResult_2UWT', 'StageRaces', 'OneDayRaces', 'StageRaceDNFs',
              'Total_KMs', 'BestGTFinish', 'WT', 'Giro',
              'numGTs', 'Days since last race']

# %%
features3 = ['Age', 'Team Leader', 'BestResult_2UWT',
              'Total_KMs', 'UCIPoints', 'StageRaces', 'OneDayRaces', 'StageRaceDNFs', 'OneDayDNFs', 'BestGTFinish',  
              'NumGTDNFs', 'numGTs', 'YearsSinceFirstGT',
              'YearsSinceLastGT', 'Giro', 'numGTs_Team', 'BestGTFinish_Team','Days since last race']

# %%
features4 = ['Age', 'Days since last race', 'BestResult_2UWT', 
             'Total_KMs', 'UCIPoints', 'StageRaceDNFs','Team Leader','YearsSinceFirstGT',
             'BestGTFinish', 'NumGTDNFs', 'numGTs', 'YearsSinceLastGT', 'Giro', 'WT', 'Age_Team','BestGTFinish_Team']

# %% [markdown]
# # Run Models

# %%
tf_linearModel = tf_linpredictor(tdf_train, "GC", features4, 2020, "year", 200, 32)
# Out:
# Epoch 1/200
# 65/65 [==============================] - 0s 468us/step - loss: 8397.0801 - accuracy: 0.0019
# Epoch 2/200
# 65/65 [==============================] - 0s 436us/step - loss: 5605.6196 - accuracy: 0.0063
# Epoch 3/200
# 65/65 [==============================] - 0s 468us/step - loss: 1865.8468 - accuracy: 0.0063
# Epoch 4/200
# 65/65 [==============================] - 0s 483us/step - loss: 1582.5453 - accuracy: 0.0063
# Epoch 5/200
# 65/65 [==============================] - 0s 499us/step - loss: 1344.0184 - accuracy: 0.0063
# Epoch 6/200
# 65/65 [==============================] - 0s 499us/step - loss: 1137.2200 - accuracy: 0.0063
# Epoch 7/200
# 65/65 [==============================] - 0s 483us/step - loss: 991.5649 - accuracy: 0.0063
# Epoch 8/200
# 65/65 [==============================] - 0s 483us/step - loss: 912.2555 - accuracy: 0.0063
# Epoch 9/200
# 65/65 [==============================] - 0s 499us/step - loss: 878.5716 - accuracy: 0.0063
# Epoch 10/200
# 65/65 [==============================] - 0s 483us/step - loss: 860.3686 - accuracy: 0.0063
# Epoch 11/200
# 65/65 [==============================] - 0s 483us/step - loss: 854.9920 - accuracy: 0.0063
# Epoch 12/200
# 65/65 [==============================] - 0s 467us/step - loss: 846.6652 - accuracy: 0.0063
# Epoch 13/200
# 65/65 [==============================] - 0s 468us/step - loss: 838.7965 - accuracy: 0.0063
# Epoch 14/200
# 65/65 [==============================] - 0s 483us/step - loss: 834.2182 - accuracy: 0.0063
# Epoch 15/200
# 65/65 [==============================] - 0s 483us/step - loss: 831.5195 - accuracy: 0.0063
# Epoch 16/200
# 65/65 [==============================] - 0s 483us/step - loss: 827.7716 - accuracy: 0.0063
# Epoch 17/200
# 65/65 [==============================] - 0s 483us/step - loss: 828.0340 - accuracy: 0.0063
# Epoch 18/200
# 65/65 [==============================] - 0s 468us/step - loss: 828.4183 - accuracy: 0.0063
# Epoch 19/200
# 65/65 [==============================] - 0s 483us/step - loss: 828.6172 - accuracy: 0.0063
# Epoch 20/200
# 65/65 [==============================] - 0s 468us/step - loss: 829.5138 - accuracy: 0.0063
# Epoch 21/200
# 65/65 [==============================] - 0s 468us/step - loss: 824.2298 - accuracy: 0.0063
# Epoch 22/200
# 65/65 [==============================] - 0s 452us/step - loss: 821.6769 - accuracy: 0.0063
# Epoch 23/200
# 65/65 [==============================] - 0s 452us/step - loss: 823.7874 - accuracy: 0.0063
# Epoch 24/200
# 65/65 [==============================] - 0s 467us/step - loss: 823.1923 - accuracy: 0.0063
# Epoch 25/200
# 65/65 [==============================] - 0s 483us/step - loss: 819.5916 - accuracy: 0.0063
# Epoch 26/200
# 65/65 [==============================] - 0s 468us/step - loss: 822.2427 - accuracy: 0.0063
# Epoch 27/200
# 65/65 [==============================] - 0s 452us/step - loss: 820.9514 - accuracy: 0.0063
# Epoch 28/200
# 65/65 [==============================] - 0s 468us/step - loss: 819.7871 - accuracy: 0.0063
# Epoch 29/200
# 65/65 [==============================] - 0s 452us/step - loss: 819.3143 - accuracy: 0.0063
# Epoch 30/200
# 65/65 [==============================] - 0s 452us/step - loss: 818.5325 - accuracy: 0.0063
# Epoch 31/200
# 65/65 [==============================] - 0s 452us/step - loss: 820.3516 - accuracy: 0.0063
# Epoch 32/200
# 65/65 [==============================] - 0s 452us/step - loss: 826.2316 - accuracy: 0.0063
# Epoch 33/200
# 65/65 [==============================] - 0s 452us/step - loss: 819.9345 - accuracy: 0.0063
# Epoch 34/200
# 65/65 [==============================] - 0s 452us/step - loss: 818.3835 - accuracy: 0.0063
# Epoch 35/200
# 65/65 [==============================] - 0s 452us/step - loss: 817.7697 - accuracy: 0.0063
# Epoch 36/200
# 65/65 [==============================] - 0s 468us/step - loss: 819.4325 - accuracy: 0.0063
# Epoch 37/200
# 65/65 [==============================] - 0s 467us/step - loss: 823.0558 - accuracy: 0.0063
# Epoch 38/200
# 65/65 [==============================] - 0s 467us/step - loss: 821.2866 - accuracy: 0.0063
# Epoch 39/200
# 65/65 [==============================] - 0s 468us/step - loss: 819.1533 - accuracy: 0.0063
# Epoch 40/200
# 65/65 [==============================] - 0s 468us/step - loss: 823.6097 - accuracy: 0.0063
# Epoch 41/200
# 65/65 [==============================] - 0s 468us/step - loss: 817.5390 - accuracy: 0.0063
# Epoch 42/200
# 65/65 [==============================] - 0s 467us/step - loss: 818.1769 - accuracy: 0.0063
# Epoch 43/200
# 65/65 [==============================] - 0s 483us/step - loss: 816.6887 - accuracy: 0.0063
# Epoch 44/200
# 65/65 [==============================] - 0s 514us/step - loss: 823.8503 - accuracy: 0.0063
# Epoch 45/200
# 65/65 [==============================] - 0s 483us/step - loss: 820.5334 - accuracy: 0.0063
# Epoch 46/200
# 65/65 [==============================] - 0s 483us/step - loss: 819.2142 - accuracy: 0.0063
# Epoch 47/200
# 65/65 [==============================] - 0s 483us/step - loss: 818.2980 - accuracy: 0.0063
# Epoch 48/200
# 65/65 [==============================] - 0s 467us/step - loss: 817.9846 - accuracy: 0.0063
# Epoch 49/200
# 65/65 [==============================] - 0s 452us/step - loss: 817.8568 - accuracy: 0.0063
# Epoch 50/200
# 65/65 [==============================] - 0s 468us/step - loss: 816.1063 - accuracy: 0.0063
# Epoch 51/200
# 65/65 [==============================] - 0s 468us/step - loss: 821.2830 - accuracy: 0.0063
# Epoch 52/200
# 65/65 [==============================] - 0s 467us/step - loss: 818.6207 - accuracy: 0.0063
# Epoch 53/200
# 65/65 [==============================] - 0s 467us/step - loss: 819.1351 - accuracy: 0.0063
# Epoch 54/200
# 65/65 [==============================] - 0s 483us/step - loss: 819.6953 - accuracy: 0.0063
# Epoch 55/200
# 65/65 [==============================] - 0s 483us/step - loss: 825.2966 - accuracy: 0.0063
# Epoch 56/200
# 65/65 [==============================] - 0s 468us/step - loss: 815.2583 - accuracy: 0.0063
# Epoch 57/200
# 65/65 [==============================] - 0s 483us/step - loss: 814.7778 - accuracy: 0.0063
# Epoch 58/200
# 65/65 [==============================] - 0s 483us/step - loss: 816.7354 - accuracy: 0.0063
# Epoch 59/200
# 65/65 [==============================] - 0s 468us/step - loss: 814.1119 - accuracy: 0.0063
# Epoch 60/200
# 65/65 [==============================] - 0s 468us/step - loss: 812.8642 - accuracy: 0.0063
# Epoch 61/200
# 65/65 [==============================] - 0s 467us/step - loss: 815.8516 - accuracy: 0.0063
# Epoch 62/200
# 65/65 [==============================] - 0s 499us/step - loss: 811.8642 - accuracy: 0.0063
# Epoch 63/200
# 65/65 [==============================] - 0s 468us/step - loss: 814.3912 - accuracy: 0.0063
# Epoch 64/200
# 65/65 [==============================] - 0s 467us/step - loss: 811.0715 - accuracy: 0.0063
# Epoch 65/200
# 65/65 [==============================] - 0s 483us/step - loss: 811.5127 - accuracy: 0.0063
# Epoch 66/200
# 65/65 [==============================] - 0s 467us/step - loss: 810.6985 - accuracy: 0.0063
# Epoch 67/200
# 65/65 [==============================] - 0s 468us/step - loss: 810.2803 - accuracy: 0.0063
# Epoch 68/200
# 65/65 [==============================] - 0s 483us/step - loss: 809.5914 - accuracy: 0.0063
# Epoch 69/200
# 65/65 [==============================] - 0s 483us/step - loss: 807.6051 - accuracy: 0.0063
# Epoch 70/200
# 65/65 [==============================] - 0s 468us/step - loss: 808.6415 - accuracy: 0.0063
# Epoch 71/200
# 65/65 [==============================] - 0s 468us/step - loss: 810.4825 - accuracy: 0.0063
# Epoch 72/200
# 65/65 [==============================] - 0s 483us/step - loss: 805.9703 - accuracy: 0.0063
# Epoch 73/200
# 65/65 [==============================] - 0s 483us/step - loss: 807.4291 - accuracy: 0.0063
# Epoch 74/200
# 65/65 [==============================] - 0s 467us/step - loss: 812.1150 - accuracy: 0.0063
# Epoch 75/200
# 65/65 [==============================] - 0s 483us/step - loss: 805.4606 - accuracy: 0.0063
# Epoch 76/200
# 65/65 [==============================] - 0s 467us/step - loss: 812.8948 - accuracy: 0.0063
# Epoch 77/200
# 65/65 [==============================] - 0s 483us/step - loss: 808.4506 - accuracy: 0.0063
# Epoch 78/200
# 65/65 [==============================] - 0s 452us/step - loss: 809.4899 - accuracy: 0.0063
# Epoch 79/200
# 65/65 [==============================] - 0s 452us/step - loss: 806.9243 - accuracy: 0.0063
# Epoch 80/200
# 65/65 [==============================] - 0s 452us/step - loss: 806.9535 - accuracy: 0.0063
# Epoch 81/200
# 65/65 [==============================] - 0s 467us/step - loss: 804.9058 - accuracy: 0.0063
# Epoch 82/200
# 65/65 [==============================] - 0s 452us/step - loss: 802.6049 - accuracy: 0.0063
# Epoch 83/200
# 65/65 [==============================] - 0s 483us/step - loss: 806.8231 - accuracy: 0.0063
# Epoch 84/200
# 65/65 [==============================] - 0s 483us/step - loss: 805.5496 - accuracy: 0.0063
# Epoch 85/200
# 65/65 [==============================] - 0s 483us/step - loss: 805.4019 - accuracy: 0.0063
# Epoch 86/200
# 65/65 [==============================] - 0s 468us/step - loss: 810.2665 - accuracy: 0.0063
# Epoch 87/200
# 65/65 [==============================] - 0s 483us/step - loss: 804.1052 - accuracy: 0.0063
# Epoch 88/200
# 65/65 [==============================] - 0s 468us/step - loss: 807.4939 - accuracy: 0.0063
# Epoch 89/200
# 65/65 [==============================] - 0s 483us/step - loss: 805.4312 - accuracy: 0.0063
# Epoch 90/200
# 65/65 [==============================] - 0s 483us/step - loss: 801.6595 - accuracy: 0.0063
# Epoch 91/200
# 65/65 [==============================] - 0s 483us/step - loss: 802.2360 - accuracy: 0.0063
# Epoch 92/200
# 65/65 [==============================] - 0s 483us/step - loss: 806.0188 - accuracy: 0.0063
# Epoch 93/200
# 65/65 [==============================] - 0s 468us/step - loss: 804.4600 - accuracy: 0.0063
# Epoch 94/200
# 65/65 [==============================] - 0s 483us/step - loss: 801.7213 - accuracy: 0.0063
# Epoch 95/200
# 65/65 [==============================] - 0s 483us/step - loss: 798.9119 - accuracy: 0.0063
# Epoch 96/200
# 65/65 [==============================] - 0s 514us/step - loss: 807.9771 - accuracy: 0.0063
# Epoch 97/200
# 65/65 [==============================] - 0s 468us/step - loss: 800.8126 - accuracy: 0.0063
# Epoch 98/200
# 65/65 [==============================] - 0s 483us/step - loss: 799.8077 - accuracy: 0.0063
# Epoch 99/200
# 65/65 [==============================] - 0s 530us/step - loss: 804.0276 - accuracy: 0.0063
# Epoch 100/200
# 65/65 [==============================] - 0s 545us/step - loss: 800.5634 - accuracy: 0.0063
# Epoch 101/200
# 65/65 [==============================] - 0s 639us/step - loss: 799.7427 - accuracy: 0.0063
# Epoch 102/200
# 65/65 [==============================] - 0s 577us/step - loss: 801.6268 - accuracy: 0.0063
# Epoch 103/200
# 65/65 [==============================] - 0s 530us/step - loss: 802.4655 - accuracy: 0.0063
# Epoch 104/200
# 65/65 [==============================] - 0s 467us/step - loss: 800.5977 - accuracy: 0.0063
# Epoch 105/200
# 65/65 [==============================] - 0s 499us/step - loss: 800.9283 - accuracy: 0.0063
# Epoch 106/200
# 65/65 [==============================] - 0s 483us/step - loss: 803.0554 - accuracy: 0.0063
# Epoch 107/200
# 65/65 [==============================] - 0s 483us/step - loss: 798.7752 - accuracy: 0.0063
# Epoch 108/200
# 65/65 [==============================] - 0s 499us/step - loss: 798.6575 - accuracy: 0.0063
# Epoch 109/200
# 65/65 [==============================] - 0s 483us/step - loss: 798.2926 - accuracy: 0.0063
# Epoch 110/200
# 65/65 [==============================] - 0s 467us/step - loss: 802.8354 - accuracy: 0.0063
# Epoch 111/200
# 65/65 [==============================] - 0s 483us/step - loss: 801.1140 - accuracy: 0.0063
# Epoch 112/200
# 65/65 [==============================] - 0s 468us/step - loss: 799.6588 - accuracy: 0.0063
# Epoch 113/200
# 65/65 [==============================] - 0s 467us/step - loss: 801.1811 - accuracy: 0.0063
# Epoch 114/200
# 65/65 [==============================] - 0s 483us/step - loss: 800.4936 - accuracy: 0.0063
# Epoch 115/200
# 65/65 [==============================] - 0s 468us/step - loss: 798.5259 - accuracy: 0.0063
# Epoch 116/200
# 65/65 [==============================] - 0s 483us/step - loss: 799.8470 - accuracy: 0.0063
# Epoch 117/200
# 65/65 [==============================] - 0s 468us/step - loss: 799.2526 - accuracy: 0.0063
# Epoch 118/200
# 65/65 [==============================] - 0s 468us/step - loss: 800.0360 - accuracy: 0.0063
# Epoch 119/200
# 65/65 [==============================] - 0s 468us/step - loss: 797.0785 - accuracy: 0.0063
# Epoch 120/200
# 65/65 [==============================] - 0s 483us/step - loss: 797.2518 - accuracy: 0.0063
# Epoch 121/200
# 65/65 [==============================] - 0s 467us/step - loss: 797.3307 - accuracy: 0.0063
# Epoch 122/200
# 65/65 [==============================] - 0s 483us/step - loss: 796.3637 - accuracy: 0.0063
# Epoch 123/200
# 65/65 [==============================] - 0s 452us/step - loss: 803.0670 - accuracy: 0.0063
# Epoch 124/200
# 65/65 [==============================] - 0s 468us/step - loss: 795.5329 - accuracy: 0.0063
# Epoch 125/200
# 65/65 [==============================] - 0s 452us/step - loss: 804.6521 - accuracy: 0.0063
# Epoch 126/200
# 65/65 [==============================] - 0s 452us/step - loss: 802.2106 - accuracy: 0.0063
# Epoch 127/200
# 65/65 [==============================] - 0s 452us/step - loss: 795.7946 - accuracy: 0.0063
# Epoch 128/200
# 65/65 [==============================] - 0s 467us/step - loss: 797.0433 - accuracy: 0.0063
# Epoch 129/200
# 65/65 [==============================] - 0s 452us/step - loss: 796.3698 - accuracy: 0.0063
# Epoch 130/200
# 65/65 [==============================] - 0s 452us/step - loss: 807.6173 - accuracy: 0.0063
# Epoch 131/200
# 65/65 [==============================] - 0s 468us/step - loss: 800.2441 - accuracy: 0.0063
# Epoch 132/200
# 65/65 [==============================] - 0s 452us/step - loss: 794.4916 - accuracy: 0.0063
# Epoch 133/200
# 65/65 [==============================] - 0s 452us/step - loss: 795.8262 - accuracy: 0.0063
# Epoch 134/200
# 65/65 [==============================] - 0s 452us/step - loss: 795.1074 - accuracy: 0.0063
# Epoch 135/200
# 65/65 [==============================] - 0s 467us/step - loss: 797.0331 - accuracy: 0.0063
# Epoch 136/200
# 65/65 [==============================] - 0s 452us/step - loss: 795.2033 - accuracy: 0.0063
# Epoch 137/200
# 65/65 [==============================] - 0s 452us/step - loss: 798.3203 - accuracy: 0.0063
# Epoch 138/200
# 65/65 [==============================] - 0s 468us/step - loss: 794.2701 - accuracy: 0.0063
# Epoch 139/200
# 65/65 [==============================] - 0s 452us/step - loss: 796.7322 - accuracy: 0.0063
# Epoch 140/200
# 65/65 [==============================] - 0s 467us/step - loss: 795.7678 - accuracy: 0.0063
# Epoch 141/200
# 65/65 [==============================] - 0s 452us/step - loss: 795.9887 - accuracy: 0.0063
# Epoch 142/200
# 65/65 [==============================] - 0s 452us/step - loss: 794.7880 - accuracy: 0.0063
# Epoch 143/200
# 65/65 [==============================] - 0s 468us/step - loss: 792.4694 - accuracy: 0.0063
# Epoch 144/200
# 65/65 [==============================] - 0s 483us/step - loss: 794.3846 - accuracy: 0.0063
# Epoch 145/200
# 65/65 [==============================] - 0s 483us/step - loss: 793.3918 - accuracy: 0.0063
# Epoch 146/200
# 65/65 [==============================] - 0s 468us/step - loss: 794.0925 - accuracy: 0.0063
# Epoch 147/200
# 65/65 [==============================] - 0s 483us/step - loss: 794.8258 - accuracy: 0.0063
# Epoch 148/200
# 65/65 [==============================] - 0s 468us/step - loss: 794.7635 - accuracy: 0.0063
# Epoch 149/200
# 65/65 [==============================] - 0s 499us/step - loss: 795.1649 - accuracy: 0.0063
# Epoch 150/200
# 65/65 [==============================] - 0s 467us/step - loss: 794.7003 - accuracy: 0.0063
# Epoch 151/200
# 65/65 [==============================] - 0s 452us/step - loss: 793.3558 - accuracy: 0.0063
# Epoch 152/200
# 65/65 [==============================] - 0s 467us/step - loss: 795.0525 - accuracy: 0.0063
# Epoch 153/200
# 65/65 [==============================] - 0s 468us/step - loss: 795.1945 - accuracy: 0.0063
# Epoch 154/200
# 65/65 [==============================] - 0s 467us/step - loss: 795.4844 - accuracy: 0.0063
# Epoch 155/200
# 65/65 [==============================] - 0s 468us/step - loss: 790.4707 - accuracy: 0.0063
# Epoch 156/200
# 65/65 [==============================] - 0s 483us/step - loss: 793.5949 - accuracy: 0.0063
# Epoch 157/200
# 65/65 [==============================] - 0s 499us/step - loss: 795.6685 - accuracy: 0.0063
# Epoch 158/200
# 65/65 [==============================] - 0s 483us/step - loss: 791.8270 - accuracy: 0.0063
# Epoch 159/200
# 65/65 [==============================] - 0s 514us/step - loss: 792.8392 - accuracy: 0.0063
# Epoch 160/200
# 65/65 [==============================] - 0s 483us/step - loss: 796.9904 - accuracy: 0.0063
# Epoch 161/200
# 65/65 [==============================] - 0s 499us/step - loss: 794.0629 - accuracy: 0.0063
# Epoch 162/200
# 65/65 [==============================] - 0s 483us/step - loss: 793.5790 - accuracy: 0.0063
# Epoch 163/200
# 65/65 [==============================] - 0s 499us/step - loss: 792.2499 - accuracy: 0.0063
# Epoch 164/200
# 65/65 [==============================] - 0s 514us/step - loss: 793.3689 - accuracy: 0.0063
# Epoch 165/200
# 65/65 [==============================] - 0s 561us/step - loss: 798.0812 - accuracy: 0.0063
# Epoch 166/200
# 65/65 [==============================] - 0s 608us/step - loss: 793.8682 - accuracy: 0.0063
# Epoch 167/200
# 65/65 [==============================] - 0s 561us/step - loss: 793.7385 - accuracy: 0.0063
# Epoch 168/200
# 65/65 [==============================] - 0s 545us/step - loss: 791.8315 - accuracy: 0.0063
# Epoch 169/200
# 65/65 [==============================] - 0s 545us/step - loss: 795.8958 - accuracy: 0.0063
# Epoch 170/200
# 65/65 [==============================] - 0s 499us/step - loss: 792.0275 - accuracy: 0.0063
# Epoch 171/200
# 65/65 [==============================] - 0s 545us/step - loss: 791.5445 - accuracy: 0.0063
# Epoch 172/200
# 65/65 [==============================] - 0s 467us/step - loss: 792.2609 - accuracy: 0.0063
# Epoch 173/200
# 65/65 [==============================] - 0s 467us/step - loss: 793.9495 - accuracy: 0.0063
# Epoch 174/200
# 65/65 [==============================] - 0s 483us/step - loss: 795.4581 - accuracy: 0.0063
# Epoch 175/200
# 65/65 [==============================] - 0s 468us/step - loss: 792.3221 - accuracy: 0.0063
# Epoch 176/200
# 65/65 [==============================] - 0s 467us/step - loss: 791.4905 - accuracy: 0.0063
# Epoch 177/200
# 65/65 [==============================] - 0s 452us/step - loss: 793.3419 - accuracy: 0.0063
# Epoch 178/200
# 65/65 [==============================] - 0s 483us/step - loss: 796.1541 - accuracy: 0.0063
# Epoch 179/200
# 65/65 [==============================] - 0s 467us/step - loss: 793.4349 - accuracy: 0.0063
# Epoch 180/200
# 65/65 [==============================] - 0s 483us/step - loss: 791.3661 - accuracy: 0.0063
# Epoch 181/200
# 65/65 [==============================] - 0s 545us/step - loss: 795.0947 - accuracy: 0.0063
# Epoch 182/200
# 65/65 [==============================] - 0s 530us/step - loss: 792.5291 - accuracy: 0.0063
# Epoch 183/200
# 65/65 [==============================] - 0s 592us/step - loss: 794.2623 - accuracy: 0.0063
# Epoch 184/200
# 65/65 [==============================] - 0s 608us/step - loss: 790.8363 - accuracy: 0.0063
# Epoch 185/200
# 65/65 [==============================] - 0s 561us/step - loss: 796.8145 - accuracy: 0.0063
# Epoch 186/200
# 65/65 [==============================] - 0s 561us/step - loss: 794.0950 - accuracy: 0.0063
# Epoch 187/200
# 65/65 [==============================] - 0s 514us/step - loss: 794.4305 - accuracy: 0.0063
# Epoch 188/200
# 65/65 [==============================] - 0s 467us/step - loss: 791.5336 - accuracy: 0.0063
# Epoch 189/200
# 65/65 [==============================] - 0s 468us/step - loss: 794.5631 - accuracy: 0.0063
# Epoch 190/200
# 65/65 [==============================] - 0s 483us/step - loss: 791.1003 - accuracy: 0.0063
# Epoch 191/200
# 65/65 [==============================] - 0s 468us/step - loss: 791.7981 - accuracy: 0.0063
# Epoch 192/200
# 65/65 [==============================] - 0s 483us/step - loss: 791.4406 - accuracy: 0.0063
# Epoch 193/200
# 65/65 [==============================] - 0s 483us/step - loss: 790.2769 - accuracy: 0.0063
# Epoch 194/200
# 65/65 [==============================] - 0s 483us/step - loss: 793.6509 - accuracy: 0.0063
# Epoch 195/200
# 65/65 [==============================] - 0s 483us/step - loss: 790.5422 - accuracy: 0.0063
# Epoch 196/200
# 65/65 [==============================] - 0s 514us/step - loss: 791.8364 - accuracy: 0.0063
# Epoch 197/200
# 65/65 [==============================] - 0s 499us/step - loss: 790.7987 - accuracy: 0.0063
# Epoch 198/200
# 65/65 [==============================] - 0s 436us/step - loss: 792.2183 - accuracy: 0.0063
# Epoch 199/200
# 65/65 [==============================] - 0s 514us/step - loss: 790.5035 - accuracy: 0.0063
# Epoch 200/200
# 65/65 [==============================] - 0s 483us/step - loss: 791.2841 - accuracy: 0.0063
#                     Rider    GC  Prediction_Ranked  Prediction
# 0           POGAČAR TADEJ   1.0                  1    0.326320
# 2              YATES ADAM   9.0                  2    0.585989
# 0           PINOT THIBAUT  29.0                  3    3.180756
# 0      LÓPEZ MIGUEL ÁNGEL   6.0                  4    5.654111
# 0          QUINTANA NAIRO  17.0                  5    6.986652
# 0            DUMOULIN TOM   7.0                  6   10.653196
# 0        MARTIN GUILLAUME  11.0                  7   11.258402
# 0             LANDA MIKEL   4.0                  8   12.273592
# 1          BENNETT GEORGE  34.0                  9   13.099360
# 1            PORTE RICHIE   3.0                 10   14.953220
# 0          URÁN RIGOBERTO   8.0                 11   19.002155
# 0          CHAVES ESTEBAN  23.0                 12   20.020695
# 7      VALVERDE ALEJANDRO  12.0                 13   20.557724
# 0            BENOOT TIESJ  75.0                 14   22.031633
# 1      ALAPHILIPPE JULIAN  36.0                 15   22.079273
# 0           SIVAKOV PAVEL  87.0                 16   25.716156
# 0              MARTIN DAN  41.0                 17   25.828867
# 0         CARAPAZ RICHARD  13.0                 18   26.203472
# 1          BARGUIL WARREN  14.0                 19   26.416004
# 0          ROLLAND PIERRE  18.0                 20   30.245358
# 3         LUTSENKO ALEXEY  46.0                 21   31.316912
# 0   SCHACHMANN MAXIMILIAN  57.0                 22   31.487728
# 0  MARTÍNEZ DANIEL FELIPE  28.0                 23   33.868843
# 0             JUNGELS BOB  43.0                 24   34.685307
# 0           ROGLIČ PRIMOŽ   2.0                 25   35.143166
# 0               MAS ENRIC   5.0                 26   35.435448
# 2        BUCHMANN EMANUEL  38.0                 27   35.826660
# 0        MADOUAS VALENTIN  27.0                 28   36.545132
# 2              SOLER MARC  21.0                 29   37.457222
# 2             MOLARD RUDY  39.0                 30   37.537155
# Checking accuracy scores for Prediction:
# Explained variance regression score: 0.6311173759151798
# Maximum residual error: 72.50726318359375
# Mean absolute error regression loss: 21.71796233201849
# Mean squared error regression loss: 792.3015977047538
# Mean squared logarithmic error regression loss.0.35255442527187997
# Median absolute error regression loss: 16.211471557617188
# Regression score function (R^2): 0.5555002735141126
# Mean Poisson deviance regression loss: 12.350045172206014
# Mean Tweedie deviance regression loss: 792.3015977047538
#
#
# Checking accuracy scores for Prediction Ranked:
# Explained variance regression score: 0.6730191324851994
# Maximum residual error: 79.0
# Mean absolute error regression loss: 18.03448275862069
# Mean squared error regression loss: 582.9172413793103
# Mean squared logarithmic error regression loss.0.30972989952208235
# Median absolute error regression loss: 14.0
# Regression score function (R^2): 0.6729697944474349
# Mean Poisson deviance regression loss: 11.456735815683345
# Mean Tweedie deviance regression loss: 582.9172413793103

# %%
tf_linearModel = tf_linpredictor_huber(tdf_train, "GC", features4, 2020, "year", 200, 32)
# Out:
# Epoch 1/200
# 65/65 [==============================] - 0s 545us/step - loss: 78.7662 - accuracy: 0.0024
# Epoch 2/200
# 65/65 [==============================] - 0s 530us/step - loss: 61.0534 - accuracy: 0.0063
# Epoch 3/200
# 65/65 [==============================] - 0s 514us/step - loss: 35.5967 - accuracy: 0.0063
# Epoch 4/200
# 65/65 [==============================] - 0s 514us/step - loss: 32.2778 - accuracy: 0.0063
# Epoch 5/200
# 65/65 [==============================] - 0s 514us/step - loss: 28.7953 - accuracy: 0.0063
# Epoch 6/200
# 65/65 [==============================] - 0s 514us/step - loss: 25.3774 - accuracy: 0.0063
# Epoch 7/200
# 65/65 [==============================] - 0s 499us/step - loss: 23.3904 - accuracy: 0.0063
# Epoch 8/200
# 65/65 [==============================] - 0s 499us/step - loss: 22.7679 - accuracy: 0.0063
# Epoch 9/200
# 65/65 [==============================] - 0s 514us/step - loss: 22.5302 - accuracy: 0.0063
# Epoch 10/200
# 65/65 [==============================] - 0s 514us/step - loss: 22.4128 - accuracy: 0.0063
# Epoch 11/200
# 65/65 [==============================] - 0s 499us/step - loss: 22.2015 - accuracy: 0.0063
# Epoch 12/200
# 65/65 [==============================] - 0s 483us/step - loss: 22.0384 - accuracy: 0.0063
# Epoch 13/200
# 65/65 [==============================] - 0s 483us/step - loss: 21.9957 - accuracy: 0.0063
# Epoch 14/200
# 65/65 [==============================] - 0s 468us/step - loss: 21.9081 - accuracy: 0.0063
# Epoch 15/200
# 65/65 [==============================] - 0s 468us/step - loss: 21.9344 - accuracy: 0.0063
# Epoch 16/200
# 65/65 [==============================] - 0s 483us/step - loss: 21.8709 - accuracy: 0.0063
# Epoch 17/200
# 65/65 [==============================] - 0s 499us/step - loss: 21.8253 - accuracy: 0.0063
# Epoch 18/200
# 65/65 [==============================] - 0s 483us/step - loss: 21.8014 - accuracy: 0.0063
# Epoch 19/200
# 65/65 [==============================] - 0s 483us/step - loss: 21.7972 - accuracy: 0.0063
# Epoch 20/200
# 65/65 [==============================] - 0s 467us/step - loss: 21.7984 - accuracy: 0.0063
# Epoch 21/200
# 65/65 [==============================] - 0s 467us/step - loss: 21.7933 - accuracy: 0.0063
# Epoch 22/200
# 65/65 [==============================] - 0s 530us/step - loss: 21.8697 - accuracy: 0.0063
# Epoch 23/200
# 65/65 [==============================] - 0s 561us/step - loss: 21.8282 - accuracy: 0.0063
# Epoch 24/200
# 65/65 [==============================] - 0s 561us/step - loss: 21.8434 - accuracy: 0.0063
# Epoch 25/200
# 65/65 [==============================] - 0s 585us/step - loss: 21.8482 - accuracy: 0.0063
# Epoch 26/200
# 65/65 [==============================] - 0s 530us/step - loss: 21.7908 - accuracy: 0.0063
# Epoch 27/200
# 65/65 [==============================] - 0s 514us/step - loss: 21.7525 - accuracy: 0.0063
# Epoch 28/200
# 65/65 [==============================] - 0s 499us/step - loss: 21.7746 - accuracy: 0.0063
# Epoch 29/200
# 65/65 [==============================] - 0s 499us/step - loss: 21.8063 - accuracy: 0.0063
# Epoch 30/200
# 65/65 [==============================] - 0s 483us/step - loss: 21.7464 - accuracy: 0.0063
# Epoch 31/200
# 65/65 [==============================] - 0s 545us/step - loss: 21.6799 - accuracy: 0.0063
# Epoch 32/200
# 65/65 [==============================] - 0s 592us/step - loss: 21.8464 - accuracy: 0.0063
# Epoch 33/200
# 65/65 [==============================] - 0s 600us/step - loss: 21.7371 - accuracy: 0.0063
# Epoch 34/200
# 65/65 [==============================] - 0s 577us/step - loss: 21.7884 - accuracy: 0.0063
# Epoch 35/200
# 65/65 [==============================] - 0s 577us/step - loss: 21.7269 - accuracy: 0.0063
# Epoch 36/200
# 65/65 [==============================] - 0s 483us/step - loss: 21.7778 - accuracy: 0.0063
# Epoch 37/200
# 65/65 [==============================] - 0s 468us/step - loss: 21.7079 - accuracy: 0.0063
# Epoch 38/200
# 65/65 [==============================] - 0s 483us/step - loss: 21.7677 - accuracy: 0.0063
# Epoch 39/200
# 65/65 [==============================] - 0s 468us/step - loss: 21.7803 - accuracy: 0.0063
# Epoch 40/200
# 65/65 [==============================] - 0s 467us/step - loss: 21.7030 - accuracy: 0.0063
# Epoch 41/200
# 65/65 [==============================] - 0s 468us/step - loss: 21.7282 - accuracy: 0.0063
# Epoch 42/200
# 65/65 [==============================] - 0s 468us/step - loss: 21.7156 - accuracy: 0.0063
# Epoch 43/200
# 65/65 [==============================] - 0s 468us/step - loss: 21.7255 - accuracy: 0.0063
# Epoch 44/200
# 65/65 [==============================] - 0s 467us/step - loss: 21.7521 - accuracy: 0.0063
# Epoch 45/200
# 65/65 [==============================] - 0s 483us/step - loss: 21.7054 - accuracy: 0.0063
# Epoch 46/200
# 65/65 [==============================] - 0s 452us/step - loss: 21.6932 - accuracy: 0.0063
# Epoch 47/200
# 65/65 [==============================] - 0s 483us/step - loss: 21.7103 - accuracy: 0.0063
# Epoch 48/200
# 65/65 [==============================] - 0s 467us/step - loss: 21.7863 - accuracy: 0.0063
# Epoch 49/200
# 65/65 [==============================] - 0s 467us/step - loss: 21.7832 - accuracy: 0.0063
# Epoch 50/200
# 65/65 [==============================] - 0s 467us/step - loss: 21.8266 - accuracy: 0.0063
# Epoch 51/200
# 65/65 [==============================] - 0s 468us/step - loss: 21.7166 - accuracy: 0.0063
# Epoch 52/200
# 65/65 [==============================] - 0s 483us/step - loss: 21.6857 - accuracy: 0.0063
# Epoch 53/200
# 65/65 [==============================] - 0s 467us/step - loss: 21.6907 - accuracy: 0.0063
# Epoch 54/200
# 65/65 [==============================] - 0s 468us/step - loss: 21.7201 - accuracy: 0.0063
# Epoch 55/200
# 65/65 [==============================] - 0s 468us/step - loss: 21.6793 - accuracy: 0.0063
# Epoch 56/200
# 65/65 [==============================] - 0s 468us/step - loss: 21.7345 - accuracy: 0.0063
# Epoch 57/200
# 65/65 [==============================] - 0s 483us/step - loss: 21.7112 - accuracy: 0.0063
# Epoch 58/200
# 65/65 [==============================] - 0s 499us/step - loss: 21.7229 - accuracy: 0.0063
# Epoch 59/200
# 65/65 [==============================] - 0s 483us/step - loss: 21.6965 - accuracy: 0.0063
# Epoch 60/200
# 65/65 [==============================] - 0s 499us/step - loss: 21.7286 - accuracy: 0.0063
# Epoch 61/200
# 65/65 [==============================] - 0s 499us/step - loss: 21.7116 - accuracy: 0.0063
# Epoch 62/200
# 65/65 [==============================] - 0s 483us/step - loss: 21.7285 - accuracy: 0.0063
# Epoch 63/200
# 65/65 [==============================] - 0s 468us/step - loss: 21.7380 - accuracy: 0.0063
# Epoch 64/200
# 65/65 [==============================] - 0s 483us/step - loss: 21.7318 - accuracy: 0.0063
# Epoch 65/200
# 65/65 [==============================] - 0s 530us/step - loss: 21.7883 - accuracy: 0.0063
# Epoch 66/200
# 65/65 [==============================] - 0s 608us/step - loss: 21.7007 - accuracy: 0.0063
# Epoch 67/200
# 65/65 [==============================] - 0s 639us/step - loss: 21.7746 - accuracy: 0.0063
# Epoch 68/200
# 65/65 [==============================] - 0s 577us/step - loss: 21.6805 - accuracy: 0.0063
# Epoch 69/200
# 65/65 [==============================] - 0s 545us/step - loss: 21.7275 - accuracy: 0.0063
# Epoch 70/200
# 65/65 [==============================] - 0s 530us/step - loss: 21.6653 - accuracy: 0.0063
# Epoch 71/200
# 65/65 [==============================] - 0s 499us/step - loss: 21.6771 - accuracy: 0.0063
# Epoch 72/200
# 65/65 [==============================] - 0s 499us/step - loss: 21.7306 - accuracy: 0.0063
# Epoch 73/200
# 65/65 [==============================] - 0s 842us/step - loss: 21.6778 - accuracy: 0.0063
# Epoch 74/200
# 65/65 [==============================] - 0s 592us/step - loss: 21.7612 - accuracy: 0.0063
# Epoch 75/200
# 65/65 [==============================] - 0s 561us/step - loss: 21.6928 - accuracy: 0.0063
# Epoch 76/200
# 65/65 [==============================] - 0s 514us/step - loss: 21.6547 - accuracy: 0.0063
# Epoch 77/200
# 65/65 [==============================] - 0s 530us/step - loss: 21.7017 - accuracy: 0.0063
# Epoch 78/200
# 65/65 [==============================] - 0s 530us/step - loss: 21.6600 - accuracy: 0.0063
# Epoch 79/200
# 65/65 [==============================] - 0s 654us/step - loss: 21.6650 - accuracy: 0.0063
# Epoch 80/200
# 65/65 [==============================] - 0s 608us/step - loss: 21.7564 - accuracy: 0.0063
# Epoch 81/200
# 65/65 [==============================] - 0s 577us/step - loss: 21.7164 - accuracy: 0.0063
# Epoch 82/200
# 65/65 [==============================] - 0s 545us/step - loss: 21.6775 - accuracy: 0.0063
# Epoch 83/200
# 65/65 [==============================] - 0s 545us/step - loss: 21.6785 - accuracy: 0.0063
# Epoch 84/200
# 65/65 [==============================] - 0s 499us/step - loss: 21.6941 - accuracy: 0.0063
# Epoch 85/200
# 65/65 [==============================] - 0s 499us/step - loss: 21.6399 - accuracy: 0.0063
# Epoch 86/200
# 65/65 [==============================] - 0s 467us/step - loss: 21.6837 - accuracy: 0.0063
# Epoch 87/200
# 65/65 [==============================] - 0s 483us/step - loss: 21.7303 - accuracy: 0.0063
# Epoch 88/200
# 65/65 [==============================] - 0s 545us/step - loss: 21.6604 - accuracy: 0.0063
# Epoch 89/200
# 65/65 [==============================] - 0s 592us/step - loss: 21.7239 - accuracy: 0.0063
# Epoch 90/200
# 65/65 [==============================] - 0s 577us/step - loss: 21.6904 - accuracy: 0.0063
# Epoch 91/200
# 65/65 [==============================] - 0s 499us/step - loss: 21.7494 - accuracy: 0.0063
# Epoch 92/200
# 65/65 [==============================] - 0s 514us/step - loss: 21.6776 - accuracy: 0.0063
# Epoch 93/200
# 65/65 [==============================] - 0s 483us/step - loss: 21.6651 - accuracy: 0.0063
# Epoch 94/200
# 65/65 [==============================] - 0s 483us/step - loss: 21.6654 - accuracy: 0.0063
# Epoch 95/200
# 65/65 [==============================] - 0s 514us/step - loss: 21.6385 - accuracy: 0.0063
# Epoch 96/200
# 65/65 [==============================] - 0s 467us/step - loss: 21.7582 - accuracy: 0.0063
# Epoch 97/200
# 65/65 [==============================] - 0s 499us/step - loss: 21.6548 - accuracy: 0.0063
# Epoch 98/200
# 65/65 [==============================] - 0s 514us/step - loss: 21.6786 - accuracy: 0.0063
# Epoch 99/200
# 65/65 [==============================] - 0s 639us/step - loss: 21.6497 - accuracy: 0.0063
# Epoch 100/200
# 65/65 [==============================] - 0s 499us/step - loss: 21.6548 - accuracy: 0.0063
# Epoch 101/200
# 65/65 [==============================] - 0s 468us/step - loss: 21.6780 - accuracy: 0.0063
# Epoch 102/200
# 65/65 [==============================] - 0s 483us/step - loss: 21.8411 - accuracy: 0.0063
# Epoch 103/200
# 65/65 [==============================] - 0s 483us/step - loss: 21.6528 - accuracy: 0.0063
# Epoch 104/200
# 65/65 [==============================] - 0s 483us/step - loss: 21.6761 - accuracy: 0.0063
# Epoch 105/200
# 65/65 [==============================] - 0s 467us/step - loss: 21.6738 - accuracy: 0.0063
# Epoch 106/200
# 65/65 [==============================] - 0s 468us/step - loss: 21.7186 - accuracy: 0.0063
# Epoch 107/200
# 65/65 [==============================] - 0s 468us/step - loss: 21.6975 - accuracy: 0.0063
# Epoch 108/200
# 65/65 [==============================] - 0s 483us/step - loss: 21.7068 - accuracy: 0.0063
# Epoch 109/200
# 65/65 [==============================] - 0s 468us/step - loss: 21.6473 - accuracy: 0.0063
# Epoch 110/200
# 65/65 [==============================] - 0s 452us/step - loss: 21.7287 - accuracy: 0.0063
# Epoch 111/200
# 65/65 [==============================] - 0s 483us/step - loss: 21.7044 - accuracy: 0.0063
# Epoch 112/200
# 65/65 [==============================] - 0s 468us/step - loss: 21.6571 - accuracy: 0.0063
# Epoch 113/200
# 65/65 [==============================] - 0s 483us/step - loss: 21.7645 - accuracy: 0.0063
# Epoch 114/200
# 65/65 [==============================] - 0s 483us/step - loss: 21.7891 - accuracy: 0.0063
# Epoch 115/200
# 65/65 [==============================] - 0s 483us/step - loss: 21.7107 - accuracy: 0.0063
# Epoch 116/200
# 65/65 [==============================] - 0s 483us/step - loss: 21.7004 - accuracy: 0.0063
# Epoch 117/200
# 65/65 [==============================] - 0s 483us/step - loss: 21.6353 - accuracy: 0.0063
# Epoch 118/200
# 65/65 [==============================] - 0s 499us/step - loss: 21.6870 - accuracy: 0.0063
# Epoch 119/200
# 65/65 [==============================] - 0s 467us/step - loss: 21.7234 - accuracy: 0.0063
# Epoch 120/200
# 65/65 [==============================] - 0s 499us/step - loss: 21.7057 - accuracy: 0.0063
# Epoch 121/200
# 65/65 [==============================] - 0s 467us/step - loss: 21.6881 - accuracy: 0.0063
# Epoch 122/200
# 65/65 [==============================] - 0s 468us/step - loss: 21.7533 - accuracy: 0.0063
# Epoch 123/200
# 65/65 [==============================] - 0s 467us/step - loss: 21.6554 - accuracy: 0.0063
# Epoch 124/200
# 65/65 [==============================] - 0s 468us/step - loss: 21.6655 - accuracy: 0.0063
# Epoch 125/200
# 65/65 [==============================] - 0s 468us/step - loss: 21.7251 - accuracy: 0.0063
# Epoch 126/200
# 65/65 [==============================] - 0s 483us/step - loss: 21.6580 - accuracy: 0.0063
# Epoch 127/200
# 65/65 [==============================] - 0s 483us/step - loss: 21.6599 - accuracy: 0.0063
# Epoch 128/200
# 65/65 [==============================] - 0s 468us/step - loss: 21.7172 - accuracy: 0.0063
# Epoch 129/200
# 65/65 [==============================] - 0s 452us/step - loss: 21.6367 - accuracy: 0.0063
# Epoch 130/200
# 65/65 [==============================] - 0s 468us/step - loss: 21.6631 - accuracy: 0.0063
# Epoch 131/200
# 65/65 [==============================] - 0s 483us/step - loss: 21.7760 - accuracy: 0.0063
# Epoch 132/200
# 65/65 [==============================] - 0s 452us/step - loss: 21.6659 - accuracy: 0.0063
# Epoch 133/200
# 65/65 [==============================] - 0s 468us/step - loss: 21.7325 - accuracy: 0.0063
# Epoch 134/200
# 65/65 [==============================] - 0s 468us/step - loss: 21.6450 - accuracy: 0.0063
# Epoch 135/200
# 65/65 [==============================] - 0s 467us/step - loss: 21.6478 - accuracy: 0.0063
# Epoch 136/200
# 65/65 [==============================] - 0s 467us/step - loss: 21.6237 - accuracy: 0.0063
# Epoch 137/200
# 65/65 [==============================] - 0s 452us/step - loss: 21.7420 - accuracy: 0.0063
# Epoch 138/200
# 65/65 [==============================] - 0s 452us/step - loss: 21.6892 - accuracy: 0.0063
# Epoch 139/200
# 65/65 [==============================] - 0s 467us/step - loss: 21.6563 - accuracy: 0.0063
# Epoch 140/200
# 65/65 [==============================] - 0s 467us/step - loss: 21.6509 - accuracy: 0.0063
# Epoch 141/200
# 65/65 [==============================] - 0s 468us/step - loss: 21.6158 - accuracy: 0.0063
# Epoch 142/200
# 65/65 [==============================] - 0s 468us/step - loss: 21.6726 - accuracy: 0.0063
# Epoch 143/200
# 65/65 [==============================] - 0s 468us/step - loss: 21.6852 - accuracy: 0.0063
# Epoch 144/200
# 65/65 [==============================] - 0s 468us/step - loss: 21.6927 - accuracy: 0.0063
# Epoch 145/200
# 65/65 [==============================] - 0s 467us/step - loss: 21.6464 - accuracy: 0.0063
# Epoch 146/200
# 65/65 [==============================] - 0s 467us/step - loss: 21.6147 - accuracy: 0.0063
# Epoch 147/200
# 65/65 [==============================] - 0s 452us/step - loss: 21.6259 - accuracy: 0.0063
# Epoch 148/200
# 65/65 [==============================] - 0s 468us/step - loss: 21.6112 - accuracy: 0.0063
# Epoch 149/200
# 65/65 [==============================] - 0s 467us/step - loss: 21.6208 - accuracy: 0.0063
# Epoch 150/200
# 65/65 [==============================] - 0s 467us/step - loss: 21.6704 - accuracy: 0.0063
# Epoch 151/200
# 65/65 [==============================] - 0s 467us/step - loss: 21.6225 - accuracy: 0.0063
# Epoch 152/200
# 65/65 [==============================] - 0s 468us/step - loss: 21.6091 - accuracy: 0.0063
# Epoch 153/200
# 65/65 [==============================] - 0s 467us/step - loss: 21.6223 - accuracy: 0.0063
# Epoch 154/200
# 65/65 [==============================] - 0s 452us/step - loss: 21.6340 - accuracy: 0.0063
# Epoch 155/200
# 65/65 [==============================] - 0s 483us/step - loss: 21.6012 - accuracy: 0.0063
# Epoch 156/200
# 65/65 [==============================] - 0s 483us/step - loss: 21.7140 - accuracy: 0.0063
# Epoch 157/200
# 65/65 [==============================] - 0s 467us/step - loss: 21.5959 - accuracy: 0.0063
# Epoch 158/200
# 65/65 [==============================] - 0s 483us/step - loss: 21.6714 - accuracy: 0.0063
# Epoch 159/200
# 65/65 [==============================] - 0s 483us/step - loss: 21.6478 - accuracy: 0.0063
# Epoch 160/200
# 65/65 [==============================] - 0s 483us/step - loss: 21.5831 - accuracy: 0.0063
# Epoch 161/200
# 65/65 [==============================] - 0s 467us/step - loss: 21.5473 - accuracy: 0.0063
# Epoch 162/200
# 65/65 [==============================] - 0s 468us/step - loss: 21.5762 - accuracy: 0.0063
# Epoch 163/200
# 65/65 [==============================] - 0s 483us/step - loss: 21.6344 - accuracy: 0.0063
# Epoch 164/200
# 65/65 [==============================] - 0s 468us/step - loss: 21.6342 - accuracy: 0.0063
# Epoch 165/200
# 65/65 [==============================] - 0s 483us/step - loss: 21.6200 - accuracy: 0.0063
# Epoch 166/200
# 65/65 [==============================] - 0s 468us/step - loss: 21.6477 - accuracy: 0.0063
# Epoch 167/200
# 65/65 [==============================] - 0s 467us/step - loss: 21.6015 - accuracy: 0.0063
# Epoch 168/200
# 65/65 [==============================] - 0s 483us/step - loss: 21.5912 - accuracy: 0.0063
# Epoch 169/200
# 65/65 [==============================] - 0s 467us/step - loss: 21.5954 - accuracy: 0.0063
# Epoch 170/200
# 65/65 [==============================] - 0s 467us/step - loss: 21.5887 - accuracy: 0.0063
# Epoch 171/200
# 65/65 [==============================] - 0s 452us/step - loss: 21.5866 - accuracy: 0.0063
# Epoch 172/200
# 65/65 [==============================] - 0s 468us/step - loss: 21.6563 - accuracy: 0.0063
# Epoch 173/200
# 65/65 [==============================] - 0s 467us/step - loss: 21.5411 - accuracy: 0.0063
# Epoch 174/200
# 65/65 [==============================] - 0s 452us/step - loss: 21.6130 - accuracy: 0.0063
# Epoch 175/200
# 65/65 [==============================] - 0s 467us/step - loss: 21.6251 - accuracy: 0.0063
# Epoch 176/200
# 65/65 [==============================] - 0s 452us/step - loss: 21.5686 - accuracy: 0.0063
# Epoch 177/200
# 65/65 [==============================] - 0s 452us/step - loss: 21.5520 - accuracy: 0.0063
# Epoch 178/200
# 65/65 [==============================] - 0s 468us/step - loss: 21.5946 - accuracy: 0.0063
# Epoch 179/200
# 65/65 [==============================] - 0s 467us/step - loss: 21.5280 - accuracy: 0.0063
# Epoch 180/200
# 65/65 [==============================] - 0s 452us/step - loss: 21.6178 - accuracy: 0.0063
# Epoch 181/200
# 65/65 [==============================] - 0s 468us/step - loss: 21.5229 - accuracy: 0.0063
# Epoch 182/200
# 65/65 [==============================] - 0s 468us/step - loss: 21.6199 - accuracy: 0.0063
# Epoch 183/200
# 65/65 [==============================] - 0s 467us/step - loss: 21.5644 - accuracy: 0.0063
# Epoch 184/200
# 65/65 [==============================] - 0s 452us/step - loss: 21.5456 - accuracy: 0.0063
# Epoch 185/200
# 65/65 [==============================] - 0s 468us/step - loss: 21.5533 - accuracy: 0.0063
# Epoch 186/200
# 65/65 [==============================] - 0s 452us/step - loss: 21.5746 - accuracy: 0.0063
# Epoch 187/200
# 65/65 [==============================] - 0s 467us/step - loss: 21.5208 - accuracy: 0.0063
# Epoch 188/200
# 65/65 [==============================] - 0s 468us/step - loss: 21.5479 - accuracy: 0.0063
# Epoch 189/200
# 65/65 [==============================] - 0s 452us/step - loss: 21.5738 - accuracy: 0.0063
# Epoch 190/200
# 65/65 [==============================] - 0s 467us/step - loss: 21.5726 - accuracy: 0.0063
# Epoch 191/200
# 65/65 [==============================] - 0s 503us/step - loss: 21.5382 - accuracy: 0.0063
# Epoch 192/200
# 65/65 [==============================] - 0s 507us/step - loss: 21.5666 - accuracy: 0.0063
# Epoch 193/200
# 65/65 [==============================] - 0s 499us/step - loss: 21.5214 - accuracy: 0.0063
# Epoch 194/200
# 65/65 [==============================] - 0s 483us/step - loss: 21.5283 - accuracy: 0.0063
# Epoch 195/200
# 65/65 [==============================] - 0s 467us/step - loss: 21.5513 - accuracy: 0.0063
# Epoch 196/200
# 65/65 [==============================] - 0s 467us/step - loss: 21.5526 - accuracy: 0.0063
# Epoch 197/200
# 65/65 [==============================] - 0s 467us/step - loss: 21.4974 - accuracy: 0.0063
# Epoch 198/200
# 65/65 [==============================] - 0s 468us/step - loss: 21.5088 - accuracy: 0.0063
# Epoch 199/200
# 65/65 [==============================] - 0s 468us/step - loss: 21.5244 - accuracy: 0.0063
# Epoch 200/200
# 65/65 [==============================] - 0s 452us/step - loss: 21.5732 - accuracy: 0.0063
#                     Rider    GC  Prediction_Ranked  Prediction
# 2              YATES ADAM   9.0                  1    1.617378
# 0           POGAČAR TADEJ   1.0                  2    3.302804
# 0           PINOT THIBAUT  29.0                  3    5.230500
# 0      LÓPEZ MIGUEL ÁNGEL   6.0                  4    5.297420
# 0          QUINTANA NAIRO  17.0                  5    9.605963
# 0             LANDA MIKEL   4.0                  6   11.273294
# 0        MARTIN GUILLAUME  11.0                  7   13.497660
# 0            DUMOULIN TOM   7.0                  8   14.430902
# 0            BENOOT TIESJ  75.0                  9   16.092979
# 1            PORTE RICHIE   3.0                 10   17.501684
# 0          URÁN RIGOBERTO   8.0                 11   18.700375
# 1          BENNETT GEORGE  34.0                 12   18.770210
# 1      ALAPHILIPPE JULIAN  36.0                 13   22.044876
# 0          CHAVES ESTEBAN  23.0                 14   24.122562
# 0              MARTIN DAN  41.0                 15   25.153179
# 0           SIVAKOV PAVEL  87.0                 16   26.441431
# 7      VALVERDE ALEJANDRO  12.0                 17   26.507759
# 1          BARGUIL WARREN  14.0                 18   26.542358
# 0         CARAPAZ RICHARD  13.0                 19   27.324898
# 0   SCHACHMANN MAXIMILIAN  57.0                 20   30.242943
# 0  MARTÍNEZ DANIEL FELIPE  28.0                 21   30.503292
# 0          ROLLAND PIERRE  18.0                 22   32.112110
# 3         LUTSENKO ALEXEY  46.0                 23   32.356617
# 0           ROGLIČ PRIMOŽ   2.0                 24   32.562553
# 2        BUCHMANN EMANUEL  38.0                 25   34.463169
# 0               MAS ENRIC   5.0                 26   35.406578
# 0        MADOUAS VALENTIN  27.0                 27   35.492908
# 2              SOLER MARC  21.0                 28   36.967953
# 0             JUNGELS BOB  43.0                 29   37.497868
# 1   REICHENBACH SÉBASTIEN  24.0                 30   38.712761
# Checking accuracy scores for Prediction:
# Explained variance regression score: 0.5879409013666645
# Maximum residual error: 79.81800842285156
# Mean absolute error regression loss: 22.767140416441293
# Mean squared error regression loss: 878.8338111877466
# Mean squared logarithmic error regression loss.0.33577502802391
# Median absolute error regression loss: 16.115066528320312
# Regression score function (R^2): 0.5069536779539936
#
#
# Checking accuracy scores for Prediction Ranked:
# Explained variance regression score: 0.6651880198171872
# Maximum residual error: 76.0
# Mean absolute error regression loss: 18.24137931034483
# Mean squared error regression loss: 596.8758620689655
# Mean squared logarithmic error regression loss.0.3238248432843562
# Median absolute error regression loss: 14.0
# Regression score function (R^2): 0.6651386817794227

# %%
1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-38-9e1622b385b6> in <module>
# ----> 1 1/0
#
# ZeroDivisionError: division by zero

# %%
tf_linearModel[["Rider","Prediction_Ranked","Seconds Behind Winner"]].sort_values(by="Seconds Behind Winner").head(30)

# %%
ridgemodel.to_csv(dPath+"tdf_2019_prediction.csv", index=False)

# %%
linearmodel = FitLinearRegressionModel(tdf_train, "GC", features1, 2021)

# %%
1/0

# %%
def scatter_plot_1(df, dim1, dim2):
    # creating trace1
    trace1 = go.Scatter(
                        x = df[dim1],
                        y = df[dim2],
                        mode = "markers",
                        name = "2014",
                        marker = dict(color = 'rgba(255, 128, 255, 0.8)'),
                        text= tdf_train_fin["Rider"])

    data = [trace1]
    layout = dict(title = dim1 + 'vs' + dim2,
                  xaxis= dict(title= dim1,ticklen= 5,zeroline= False),
                  yaxis= dict(title= dim2,ticklen= 5,zeroline= False)
                 )
    fig = dict(data = data, layout = layout)
    iplot(fig)
